# %% [markdown]
# # Attention U-Net: xBD Bina Hasar Tespiti Eğitimi
# Bu notebook, projenin Colab üzerinde otomatik olarak eğitilmesini sağlar.
#
# **Adımlar:**
# 1. GitHub reposunu clone'lar.
# 2. Kaggle'dan veri setini indirir.
# 3. Eğitimi başlatır.

# %%
# 1. Repoyu Clone'la (Kendi repo URL'ni buraya yaz)
REPO_URL = "YOUR_GITHUB_REPO_URL_HERE"
# !git clone $REPO_URL project
# %cd project

# %%
# 2. Kaggle Kimlik Bilgilerini Ayarla
from google.colab import files
import os

if not os.path.exists('/root/.kaggle/kaggle.json'):
    print("kaggle.json dosyasını yükleyin:")
    files.upload()
    # !mkdir -p ~/.kaggle
    # !cp kaggle.json ~/.kaggle/
    # !chmod 600 ~/.kaggle/kaggle.json

# %%
# 3. Veri Setini İndir ve Hazırla
# !mkdir -p data/xbd
# !kaggle datasets download -d tunguz/xview2-challenge-dataset-train-and-test -p data/xbd --unzip

# %%
# 4. Bağımlılıkları Yükle
# !pip install shapely opencv-python

# %%
# 5. Eğitimi Başlat
# !python -m src.train --epochs 20 --batch_size 16
